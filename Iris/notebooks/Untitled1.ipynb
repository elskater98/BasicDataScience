# %% [markdown]
# # Iris

# %% [markdown]
# ## 1. Read data

# %% [markdown]
# **set up
#
# We can start import the libraries (pandas, numpy, seaborn) and load the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

sns.set(style="whitegrid", palette="muted")
dfIris = pd.read_csv('../src/data/raw/iris.data')
print(dfIris)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# # 2.setting

# %% [markdown]
# ### Naming columns
#
# First of all, we check the information of data.
# We need to name the colums since there's no column names.
# It is noticable that 'class label' is the only object type.

# %%
#column naming & check info
#dfIris.info()
dfIris.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class label']
dfIris.info()
#only class column is the object type
#other columns are value columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  149 non-null    float64
#  1   sepal width   149 non-null    float64
#  2   petal length  149 non-null    float64
#  3   petal width   149 non-null    float64
#  4   class label   149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ### Reshaping data
#
# We want to see the data by class label.
# The data can be reshaped by melt method.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#"melt"
dfIris = pd.melt(dfIris,"class label", var_name ="measurement")
print(dfIris)
#
#sns.scatterplot()
# Out:
#         class label   measurement  value
# 0       Iris-setosa  sepal length    4.9
# 1       Iris-setosa  sepal length    4.7
# 2       Iris-setosa  sepal length    4.6
# 3       Iris-setosa  sepal length    5.0
# 4       Iris-setosa  sepal length    5.4
# ..              ...           ...    ...
# 591  Iris-virginica   petal width    2.3
# 592  Iris-virginica   petal width    1.9
# 593  Iris-virginica   petal width    2.0
# 594  Iris-virginica   petal width    2.3
# 595  Iris-virginica   petal width    1.8
#
# [596 rows x 3 columns]

# %% [markdown]
# ## 3.Data Exploration

# %%
sns.scatterplot(x="measurement", y="value", hue="class label", data=dfIris)
# Out:
# <AxesSubplot:xlabel='measurement', ylabel='value'>

# %%
sns.swarmplot(x="measurement", y="value", hue="class label", palette=["r","c","y"],data=dfIris )
# Out:
# /home/jeongyun/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/jeongyun/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 33.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/jeongyun/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 8.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/jeongyun/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 24.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='measurement', ylabel='value'>
